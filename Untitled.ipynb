# %%
from toolkit.elastic.searcher import ElasticSearcher
# Out:
# ---------------------------------------------------------------------------
# AppRegistryNotReady                       Traceback (most recent call last)
# <ipython-input-15-28efb58aed70> in <module>
# ----> 1 from toolkit.elastic.searcher import ElasticSearcher
#
# ~/texta-rest/toolkit/elastic/searcher.py in <module>
#       5 from elasticsearch_dsl.query import MoreLikeThis
#       6
# ----> 7 from toolkit.elastic.core import ElasticCore, elastic_connection
#       8
#       9
#
# ~/texta-rest/toolkit/elastic/core.py in <module>
#      15
#      16
# ---> 17 class ElasticCore:
#      18     """
#      19         Class for holding most general settings and Elasticsearch object itself
#
# ~/texta-rest/toolkit/elastic/core.py in ElasticCore()
#      21
#      22
# ---> 23     def __init__(self, ES_URL=get_core_setting("TEXTA_ES_URL"), check_connection=True):
#      24         self.ES_URL = ES_URL
#      25         self.ES_PREFIX = get_core_setting("TEXTA_ES_PREFIX")
#
# ...

# %%
import toolkit
from toolkit.embedding import tasks
# Out:
# ---------------------------------------------------------------------------
# AppRegistryNotReady                       Traceback (most recent call last)
# <ipython-input-14-48fa0d2060af> in <module>
#       1 import toolkit
# ----> 2 from toolkit.embedding import tasks
#
# ~/texta-rest/toolkit/embedding/tasks.py in <module>
#       6
#       7 from toolkit.base_tasks import BaseTask
# ----> 8 from toolkit.core.task.models import Task
#       9 from toolkit.elastic.searcher import ElasticSearcher
#      10 from toolkit.embedding.models import Embedding
#
# ~/texta-rest/toolkit/core/task/models.py in <module>
#       5 from django.utils.timezone import now
#       6
# ----> 7 from toolkit.constants import MAX_DESC_LEN
#       8
#       9
#
# ~/texta-rest/toolkit/constants.py in <module>
# ----> 1 from toolkit.elastic.core import ElasticCore
#       2
#       3
#       4 '''For storing constant variables'''
#       5 # Default max description lenght for models
#
# ...
